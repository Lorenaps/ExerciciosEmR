# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorenaps/estudando-r/blob/master/tutorial_dadosjus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import json

# %%
r = requests.get("https://dadosjusbr.org/api/v1/orgao/trt13/2020/2")

# %%
r_json = r.json()
type(r_json)
# Out:
# list

# %%
r_json
# Out:
# [{'active': True,
#   'discounts': {'ceil_retention': 0,
#    'income_tax': -2325.61,
#    'other': {'other_discounts': 0},
#    'prev_contribution': -1039.11,
#    'total': -3364.72},
#   'income': {'other': {'daily': 0,
#     'eventual_benefits': 3920.82,
#     'gratification': 0,
#     'origin_pos': 0,
#     'others': None,
#     'person_benefits': 0,
#     'total': 3920.82,
#     'trust_position': None},
#    'perks': {'birth_aid': None,
#     'food': None,
#     'health': None,
#     'housing_aid': None,
#     'others': None,
#     'pre_school': None,
#     'subsistence': None,
#     'total': 910.08,
#     'transportation': None},
#    'total': 16593.36,
#    'wage': 11762.460000000001},
#   'name': 'LARISSA DE MACEDO FERREIRA MOTA',
#   'reg': '35688',
#   'role': 'TÉCNICO JUDICIÁRIO',
#   'type': 'servidor',
#   'workplace': '2ª VARA DO TRABALHO DE JOÃO PESSOA'},
#  {'active': True,
#   'discounts': {'ceil_retention': 0,
#    'income_tax': -1773.09,
# ...

# %%
df2 = pd.DataFrame(r_json)
df2.head()
# Out:
#      reg  ...                                          discounts
# 0  35688  ...  {'total': -3364.72, 'prev_contribution': -1039...
# 1  35140  ...  {'total': -3123.71, 'prev_contribution': -1350...
# 2   5867  ...  {'total': -4550.03, 'prev_contribution': -1474...
# 3   5929  ...  {'total': -4191.09, 'prev_contribution': -1459...
# 4   5339  ...  {'total': -7546.9, 'prev_contribution': -1784....
#
# [5 rows x 8 columns]

# %%
df = pd.json_normalize(r_json)
df.head()
# Out:
#      reg  ... discounts.other.other_discounts
# 0  35688  ...                             0.0
# 1  35140  ...                             0.0
# 2   5867  ...                             0.0
# 3   5929  ...                             0.0
# 4   5339  ...                             0.0
#
# [5 rows x 30 columns]

# %%
df.to_csv(index=False)

# %%
df[['role', 'income.total']].groupby('role').mean().sort_values("income.total", ascending=False)
# Out:
#                                                     income.total
# role
# DESEMBARGADOR FEDERAL - NÍVEL SUPERIOR DFDF         42304.718000
# JUIZ TITULAR DE VARA - NÍVEL SUPERIOR JTJT          37951.189259
# JUIZ SUBSTITUTO - NÍVEL SUPERIOR JSJS               37873.476800
# ANALISTA JUDICIÁRIO                                 24670.590893
# TÉCNICO JUDICIÁRIO                                  16794.091724
# ASSESSOR DE GESTÃO ESTRATÉGICA - CJ-02              12292.960000
# AUXILIAR JUDICIÁRIO                                  9966.170000
# SECRETÁRIO DA CORREGEDORIA - CJ-03                   9321.090000
# COORDENADOR - CJ-02                                  8308.950000
# CHEFE DA SEÇÃO DE PROCESSOS - FC-05                  4809.070000
# ASSESSOR DE COMUNICAÇÃO SOCIAL - CJ-02               4324.940000
# CHEFE DO NUCLEO DE JORNALISMO E MIDIAS SOCIAIS ...   3982.440000
# ASSISTENTE DE GABINETE IV - FC-04                    3962.340000
# ...
